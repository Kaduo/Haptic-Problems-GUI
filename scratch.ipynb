# %%
import pandas
df = pandas.read_csv("user_data/user4/eyes_u4p9.tap")

# %%
import seaborn as sns

sns.lineplot(df, x="Timestamp (ms)", y="Pitch")
# Out:
# <Axes: xlabel='Timestamp (ms)', ylabel='Pitch'>
