# %%
import pandas
df = pandas.read_csv("user_data/user5/eyes_u5p0.csv")
# df = pandas.read_csv("logs/eye_tracking_log_30-10-2024_12-53-50.csv")

# %%
df
# Out:
#      Unnamed: 0  Timestamp (ms)  Left Eye Center X  Left Eye Center Y  \
# 0             0      1730289192              457.5              233.5
# 1             1      1730289192              457.5              233.5
# 2             2      1730289192              457.0              234.0
# 3             3      1730289192              457.0              234.0
# 4             4      1730289192              457.0              233.5
# ..          ...             ...                ...                ...
# 849         849      1730289206              393.0              216.5
# 850         850      1730289206              393.0              216.5
# 851         851      1730289206              393.0              216.5
# 852         852      1730289206              393.5              216.5
# 853         853      1730289206              393.5              216.5
#
#      Right Eye Center X  Right Eye Center Y  Left Iris Relative Pos Dx  \
# ...

# %%
import seaborn as sns

sns.lineplot(df, x="Timestamp (ms)", y="Pitch", estimator=None)
# Out:
# <Axes: xlabel='Timestamp (ms)', ylabel='Pitch'>
